# %% [markdown]
# # Spaceship Titanic - Model Training
#
# This notebook trains and evaluates machine learning classifiers for the [Spaceship Titanic Kaggle competition](https://www.kaggle.com/competitions/spaceship-titanic). The goal is binary classification: predict whether a passenger was transported to an alternate dimension.
#
# ## Models Covered
# 1. **Random Forest** - Ensemble of decision trees using bagging
# 2. **XGBoost** - Gradient boosting framework (often top performer on tabular data)
# 3. **CatBoost** - Gradient boosting with native categorical feature support
# 4. **MLP (Multi-Layer Perceptron)** - Neural network for tabular classification
#
# Each model section includes hyperparameter tuning via `RandomizedSearchCV` with 5-fold stratified cross-validation.

# %% [markdown]
# # 1. Imports
#
# All required libraries for data processing and model training.

# %%
# core
import numpy as np
import pandas as pd

# sklearn - model selection & preprocessing
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score

# sklearn - models
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier

# gradient boosting libraries
from xgboost import XGBClassifier
from catboost import CatBoostClassifier

# distributions for hyperparameter search
from scipy.stats import randint, uniform
from sklearn.utils import check_random_state

# local utilities
from utils import preprocessing_pipeline as p
from utils.encoding_utils import (
    encode_features_for_ml,
    encode_features_for_xgboost,
    encode_features_for_catboost,
    get_catboost_categorical_indices
)

# %% [markdown]
# # 2. Data Loading & Preprocessing
#
# We use a custom preprocessing pipeline (`utils/preprocessing_pipeline.py`) that handles:
# - **Feature decomposition**: Extracts components from PassengerId (group info) and Cabin (deck/side)
# - **Feature construction**: Creates GroupSize, TotalSpent, spending ratios
# - **Age binning**: Uses decision-tree-based optimal binning
# - **Imputation**: Handles missing values using domain logic (e.g., CryoSleep passengers have zero spending) and KNN for remaining gaps
#
# The pipeline returns fitted parameters from training data to ensure consistent transformation on test data (preventing data leakage).

# %%
# load raw data
train_raw = pd.read_csv('data/train.csv')
test_raw = pd.read_csv('data/test.csv')

# apply preprocessing pipeline
train_processed, train_params = p.preprocess_train(train_raw)
test_processed = p.preprocess_test(test_raw, train_params)

print(f"Training samples: {len(train_processed)}")
print(f"Test samples: {len(test_processed)}")
train_processed.head()
# Out:
# Step 1: Decomposing PassengerId and Cabin...
# Step 2: Constructing features (GroupSize, TotalSpent, etc.)...
# Step 3: Binning Age into Age_Group...
# Step 4: Imputing spending and CryoSleep...
# Step 5: Imputing categorical features...
# /Users/or/Projects/MDLM_assignment/utils/preprocessing_pipeline.py:280: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['VIP'] = df['VIP'].fillna(False).infer_objects(copy=False)
# Step 6: Final CryoSleep/spending cleanup...
# Step 6b: KNN imputing remaining spending...
# Step 7: Recalculating spending features...
# Done! Training data preprocessed.
# HomePlanet      True
# CryoSleep       True
# Destination     True
# VIP             True
# RoomService     True
# FoodCourt       True
# ShoppingMall    True
# Spa             True
# VRDeck          True
# Transported     True
# Deck            True
# CabinNum        True
# Side            True
# GroupSize       True
# Age_Group       True
# dtype: bool
# Step 1: Decomposing PassengerId and Cabin...
# Step 2: Constructing features (GroupSize, TotalSpent, etc.)...
# Step 3: Applying Age binning (using train split points)...
# Step 4: Imputing spending and CryoSleep...
# Step 5: Imputing categorical features...
# Step 6: Final CryoSleep/spending cleanup...
# Step 6b: KNN imputing remaining spending (using train-fitted imputer)...
# Step 7: Recalculating spending features...
# Done! Test data preprocessed.
# Training samples: 8693
# Test samples: 4277
# /Users/or/Projects/MDLM_assignment/utils/preprocessing_pipeline.py:280: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['VIP'] = df['VIP'].fillna(False).infer_objects(copy=False)
#   HomePlanet CryoSleep  Destination    VIP  RoomService  FoodCourt  \
# 0     Europa     False  TRAPPIST-1e  False          0.0        0.0
# 1      Earth     False  TRAPPIST-1e  False        109.0        9.0
# 2     Europa     False  TRAPPIST-1e   True         43.0     3576.0
# 3     Europa     False  TRAPPIST-1e  False          0.0     1283.0
# 4      Earth     False  TRAPPIST-1e  False        303.0       70.0
#
#    ShoppingMall     Spa  VRDeck  Transported Deck  CabinNum Side  GroupSize  \
# 0           0.0     0.0     0.0        False    B       0.0    P          1
# 1          25.0   549.0    44.0         True    F       0.0    S          1
# 2           0.0  6715.0    49.0        False    A       0.0    S          2
# 3         371.0  3329.0   193.0        False    A       0.0    S          2
# 4         151.0   565.0     2.0         True    F       1.0    S          1
#
#     Age_Group
# 0  Age_Bin_11
# 1   Age_Bin_5
# 2  Age_Bin_13
# 3  Age_Bin_10
# 4   Age_Bin_3

# %% [markdown]
# # 3. Feature Encoding for ML Models
#
# Most scikit-learn models require **numeric inputs**. Our preprocessed data still contains:
# - **Boolean columns** (`CryoSleep`, `VIP`, `Transported`) → convert to 0/1
# - **Ordinal categories** (`Deck`, `Side`, `Age_Group`) → label encode (preserves ordering for tree-based models)
# - **Nominal categories** (`HomePlanet`, `Destination`) → encoding depends on model type!
#
# ## Two Encoding Strategies
#
# We provide **two encoding functions** because different models have different needs:
#
# | Model Type | Function | Categorical Encoding | Missing Values |
# |------------|----------|---------------------|----------------|
# | MLP, Logistic Regression | `encode_features_for_ml()` | One-hot | Fill with 0 |
# | XGBoost, Random Forest | `encode_features_for_xgboost()` | Label/Categorical | Keep NaN |
#
# **Why the difference?**
# - **Neural networks** treat features as continuous values. Label encoding (1, 2, 3) implies "3 is closer to 2 than to 1" which is false for categories like "Earth, Europa, Mars". One-hot avoids this.
# - **Tree-based models** make binary splits. They can naturally handle "category == X" splits without needing one-hot encoding. Fewer features = faster training and often better results.

# %%
# encoding functions are now imported from utils.encoding_utils
# 
# available functions:
#   - encode_features_for_ml(df, train_params=None)    -> for MLP, Logistic Regression (one-hot)
#   - encode_features_for_xgboost(df)                  -> for XGBoost (categorical dtype)
#   - encode_features_for_catboost(df)                 -> for CatBoost (string categoricals)
#   - get_catboost_categorical_indices(df)             -> get cat_features indices for CatBoost

print("Encoding functions loaded from utils.encoding_utils")
# Out:
# Encoding functions loaded from utils.encoding_utils

# %% [markdown]
# # 4. Train/Test Split
#
# We split the labeled training data into:
# - **70% training set** - used for model fitting and cross-validation
# - **30% holdout test set** - used for final evaluation (simulates unseen data)
#
# **Why stratified sampling?**
# The `stratify=y` parameter ensures both splits maintain the same class distribution as the original data. This is crucial for classification tasks, especially if classes are imbalanced - otherwise one split might have different class proportions leading to biased evaluation.

# %%
# encode features for ML models (pass train_params for consistent ordinal encoding)
train_encoded = encode_features_for_ml(train_processed, train_params)

# separate features and target
X = train_encoded.drop('Transported', axis=1)
y = train_encoded['Transported']

# stratified train/test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, shuffle=True, stratify=y
)

# cross-validation strategy (reused across all models)
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

print(f"Training set: {X_train.shape[0]} samples")
print(f"Test set: {X_test.shape[0]} samples")
print(f"Features: {X_train.shape[1]}")
print(f"Target distribution - Train: {y_train.mean():.2%} positive")
print(f"Target distribution - Test: {y_test.mean():.2%} positive")
# Out:
# Training set: 6085 samples
# Test set: 2608 samples
# Features: 16
# Target distribution - Train: 50.37% positive
# Target distribution - Test: 50.35% positive

# %% [markdown]
# # 5. Random Forest Classifier
#
# **Random Forest** is an ensemble method that builds multiple decision trees and aggregates their predictions (bagging). It's an excellent baseline for tabular data because:
# - Handles mixed feature types naturally
# - Robust to outliers and noise
# - Provides feature importance rankings
# - Requires minimal preprocessing (no scaling needed)
#
# ## Key Hyperparameters
#
# | Parameter | Description | Search Range |
# |-----------|-------------|--------------|
# | `n_estimators` | Number of trees in the forest | 300-700 |
# | `max_depth` | Maximum tree depth (None = unlimited) | None, 5-60 |
# | `min_samples_split` | Minimum samples to split a node | 2-30 |
# | `min_samples_leaf` | Minimum samples in a leaf | 1-20 |
# | `bootstrap` | Whether to use bootstrap sampling | True/False |
# | `class_weight` | Weighting for imbalanced classes | balanced, balanced_subsample, None |
#
# **Trade-offs:**
# - More trees (`n_estimators`) = better accuracy but slower training
# - Deeper trees (`max_depth`) = more complex patterns but risk overfitting
# - Higher `min_samples_split/leaf` = regularization, prevents overfitting

# %%
# baseline model with default hyperparameters
baseline_rf = RandomForestClassifier(
    n_estimators=600, random_state=42, class_weight="balanced", n_jobs=-1
)
baseline_scores = cross_val_score(baseline_rf, X_train, y_train, cv=cv, scoring="accuracy", n_jobs=-1)
print(f"Baseline RF CV Accuracy: {baseline_scores.mean():.4f} ± {baseline_scores.std():.4f}")

# hyperparameter search space
param_distributions_rf = {
    "n_estimators": randint(300, 700),
    "max_depth": [None] + list(range(5, 61, 5)),
    "min_samples_split": randint(2, 31),
    "min_samples_leaf": randint(1, 21),
    "bootstrap": [True, False],
    "class_weight": ["balanced", "balanced_subsample", None],
}

# randomized search with cross-validation
search_rf = RandomizedSearchCV(
    estimator=RandomForestClassifier(random_state=42, n_jobs=-1),
    param_distributions=param_distributions_rf,
    n_iter=60,
    scoring="accuracy",
    cv=cv,
    n_jobs=-1,
    random_state=42,
    verbose=1,
    refit=True,
)

search_rf.fit(X_train, y_train)

print(f"\nBest CV accuracy: {search_rf.best_score_:.4f}")
print(f"Best params: {search_rf.best_params_}")

best_rf = search_rf.best_estimator_
rf_test_acc = best_rf.score(X_test, y_test)
print(f"Test accuracy: {rf_test_acc:.4f}")
# Out:
# Baseline RF CV Accuracy: 0.7975 ± 0.0070
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
#
# Best CV accuracy: 0.8036
# Best params: {'bootstrap': True, 'class_weight': None, 'max_depth': 25, 'min_samples_leaf': 8, 'min_samples_split': 28, 'n_estimators': 436}
# Test accuracy: 0.8014

# %% [markdown]
# # 6. XGBoost Classifier
#
# **XGBoost** (eXtreme Gradient Boosting) builds trees sequentially, where each new tree corrects errors made by previous trees. Unlike Random Forest's parallel bagging, XGBoost uses **gradient boosting**:
#
# 1. Train initial model on data
# 2. Compute residual errors (gradient of loss)
# 3. Train next tree to predict residuals
# 4. Repeat, combining predictions with learning rate shrinkage
#
# ## Why XGBoost Needs Different Encoding
#
# **Critical insight**: XGBoost (and tree-based models in general) work *differently* than neural networks:
#
# | Aspect | One-Hot Encoding | Label Encoding |
# |--------|------------------|----------------|
# | **How it works** | Creates N binary columns | Single column with integers |
# | **For trees** | ❌ Fragments splits, needs multiple decisions | ✅ Single split can separate categories |
# | **For NNs** | ✅ No ordinal assumption | ❌ Implies false ordering |
#
# **Missing values**: XGBoost learns the optimal split direction for NaN values during training. Filling with 0 removes this advantage!
#
# ## Key Hyperparameters
#
# | Parameter | Description | Search Range |
# |-----------|-------------|--------------|
# | `n_estimators` | Number of boosting rounds | 100-500 |
# | `max_depth` | Maximum tree depth (keep low to prevent overfitting) | 3-10 |
# | `learning_rate` | Step size shrinkage (η) | 0.01-0.3 |
# | `subsample` | Row sampling ratio per tree | 0.6-1.0 |
# | `colsample_bytree` | Column sampling ratio per tree | 0.6-1.0 |
# | `min_child_weight` | Minimum sum of instance weight in child | 1-10 |
# | `gamma` | Minimum loss reduction for split | 0-0.5 |
#
# **Tip:** Lower `learning_rate` + more `n_estimators` = better generalization but slower training.

# %%
# use XGBoost-optimized encoding (label encoding, keep NaN)
train_xgb = encode_features_for_xgboost(train_processed)
test_xgb = encode_features_for_xgboost(test_processed)

X_xgb = train_xgb.drop('Transported', axis=1)
y_xgb = train_xgb['Transported']

X_train_xgb, X_test_xgb, y_train_xgb, y_test_xgb = train_test_split(
    X_xgb, y_xgb, test_size=0.3, random_state=42, shuffle=True, stratify=y_xgb
)

print(f"XGBoost training features: {X_train_xgb.shape[1]} (vs {X_train.shape[1]} for one-hot encoded)")
print(f"Categorical columns: {X_train_xgb.select_dtypes('category').columns.tolist()}")

# baseline XGBoost with native categorical support
baseline_xgb = XGBClassifier(
    n_estimators=300, 
    random_state=42, 
    n_jobs=-1, 
    eval_metric='logloss',
    enable_categorical=True,  # enable native categorical support
    tree_method='hist'        # required for categorical support
)
baseline_xgb_scores = cross_val_score(baseline_xgb, X_train_xgb, y_train_xgb, cv=cv, scoring="accuracy", n_jobs=-1)
print(f"\nBaseline XGBoost CV Accuracy: {baseline_xgb_scores.mean():.4f} ± {baseline_xgb_scores.std():.4f}")

# improved hyperparameter search space
param_distributions_xgb = {
    "n_estimators": randint(200, 600),
    "max_depth": randint(3, 8),                    # keep shallow to prevent overfitting
    "learning_rate": uniform(0.01, 0.19),          # 0.01 to 0.2
    "subsample": uniform(0.7, 0.3),                # 0.7 to 1.0
    "colsample_bytree": uniform(0.7, 0.3),         # 0.7 to 1.0
    "min_child_weight": randint(1, 10),
    "gamma": uniform(0, 0.3),                      # regularization
    "reg_alpha": uniform(0, 0.5),                  # L1 regularization
    "reg_lambda": uniform(0.5, 1.5),               # L2 regularization
}

# randomized search
search_xgb = RandomizedSearchCV(
    estimator=XGBClassifier(
        random_state=42, 
        n_jobs=-1, 
        eval_metric='logloss',
        enable_categorical=True,
        tree_method='hist'
    ),
    param_distributions=param_distributions_xgb,
    n_iter=80,
    scoring="accuracy",
    cv=cv,
    n_jobs=-1,
    random_state=42,
    verbose=1,
    refit=True,
)

search_xgb.fit(X_train_xgb, y_train_xgb)

print(f"\nBest CV accuracy: {search_xgb.best_score_:.4f}")
print(f"Best params: {search_xgb.best_params_}")

best_xgb = search_xgb.best_estimator_
xgb_test_acc = best_xgb.score(X_test_xgb, y_test_xgb)
print(f"Test accuracy: {xgb_test_acc:.4f}")
# Out:
# XGBoost training features: 14 (vs 16 for one-hot encoded)
# Categorical columns: ['HomePlanet', 'Destination', 'Deck', 'Side', 'Age_Group']
#
# Baseline XGBoost CV Accuracy: 0.7869 ± 0.0115
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
#
# Best CV accuracy: 0.8110
# Best params: {'colsample_bytree': np.float64(0.8691895276056508), 'gamma': np.float64(0.2522129957633793), 'learning_rate': np.float64(0.026948822455290677), 'max_depth': 6, 'min_child_weight': 9, 'n_estimators': 344, 'reg_alpha': np.float64(0.17146343213913012), 'reg_lambda': np.float64(1.2109549121458343), 'subsample': np.float64(0.8065312909837914)}
# Test accuracy: 0.8087

# %% [markdown]
# # 6b. CatBoost Classifier
#
# **CatBoost** (Categorical Boosting) is a gradient boosting library developed by Yandex that specializes in handling categorical features. Key advantages:
#
# 1. **Native Categorical Handling**: Uses target statistics with ordered boosting to encode categoricals, eliminating the need for manual encoding
# 2. **Ordered Boosting**: Prevents prediction shift (a form of target leakage) by using a permutation-based approach
# 3. **Symmetric Trees**: Uses oblivious decision trees where the same split is applied across an entire level, enabling faster inference
# 4. **GPU Support**: Efficient GPU training out of the box
#
# ## CatBoost vs XGBoost for Categorical Features
#
# | Aspect | XGBoost | CatBoost |
# |--------|---------|----------|
# | Categorical handling | Requires `enable_categorical=True` + `category` dtype | Native support, just specify `cat_features` |
# | Encoding method | One-hot or label encoding internally | Target statistics with ordered boosting |
# | Target leakage | Possible if not careful | Prevented by ordered boosting |
# | Default behavior | Treats categoricals as numeric | Proper categorical treatment |
#
# ## Key Hyperparameters
#
# | Parameter | Description | Search Range |
# |-----------|-------------|--------------|
# | `iterations` | Number of boosting rounds | 200-800 |
# | `depth` | Tree depth | 4-10 |
# | `learning_rate` | Step size shrinkage | 0.01-0.3 |
# | `l2_leaf_reg` | L2 regularization | 1-10 |
# | `bagging_temperature` | Bayesian bootstrap temperature | 0-1 |
# | `random_strength` | Randomness for scoring splits | 0-1 |
# | `border_count` | Number of splits for numerical features | 32-255 |

# %%
# encode for CatBoost (uses imported function)
train_cat = encode_features_for_catboost(train_processed)
test_cat = encode_features_for_catboost(test_processed)

X_cat = train_cat.drop('Transported', axis=1)
y_cat = train_cat['Transported']

X_train_cat, X_test_cat, y_train_cat, y_test_cat = train_test_split(
    X_cat, y_cat, test_size=0.3, random_state=42, shuffle=True, stratify=y_cat
)

# identify categorical feature indices for CatBoost
cat_features = get_catboost_categorical_indices(X_cat)
print(f"Categorical feature indices: {cat_features}")
print(f"Categorical columns: {[X_cat.columns[i] for i in cat_features]}")

# baseline CatBoost
baseline_catboost = CatBoostClassifier(
    iterations=500,
    random_seed=42,
    cat_features=cat_features,
    verbose=0,
    thread_count=-1
)
baseline_catboost_scores = cross_val_score(
    baseline_catboost, X_train_cat, y_train_cat, cv=cv, scoring="accuracy", n_jobs=-1
)
print(f"\nBaseline CatBoost CV Accuracy: {baseline_catboost_scores.mean():.4f} ± {baseline_catboost_scores.std():.4f}")

# hyperparameter search space
param_distributions_catboost = {
    "iterations": randint(300, 800),
    "depth": randint(4, 10),
    "learning_rate": uniform(0.01, 0.19),           # 0.01 to 0.2
    "l2_leaf_reg": uniform(1, 9),                   # 1 to 10
    "bagging_temperature": uniform(0, 1),           # bayesian bootstrap
    "random_strength": uniform(0, 1),               # randomness for scoring splits
    "border_count": randint(32, 255),               # splits for numerical features
}

# randomized search
search_catboost = RandomizedSearchCV(
    estimator=CatBoostClassifier(
        random_seed=42,
        cat_features=cat_features,
        verbose=0,
        thread_count=-1
    ),
    param_distributions=param_distributions_catboost,
    n_iter=80,
    scoring="accuracy",
    cv=cv,
    n_jobs=-1,
    random_state=42,
    verbose=1,
    refit=True,
)

search_catboost.fit(X_train_cat, y_train_cat)

print(f"\nBest CV accuracy: {search_catboost.best_score_:.4f}")
print(f"Best params: {search_catboost.best_params_}")

best_catboost = search_catboost.best_estimator_
catboost_test_acc = best_catboost.score(X_test_cat, y_test_cat)
print(f"Test accuracy: {catboost_test_acc:.4f}")
# Out:
# Categorical feature indices: [0, 2, 9, 11, 13]
# Categorical columns: ['HomePlanet', 'Destination', 'Deck', 'Side', 'Age_Group']
#
# Baseline CatBoost CV Accuracy: 0.8094 ± 0.0058
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
#
# Best CV accuracy: 0.8136
# Best params: {'bagging_temperature': np.float64(0.053485296747368904), 'border_count': 220, 'depth': 4, 'iterations': 702, 'l2_leaf_reg': np.float64(1.821580091075202), 'learning_rate': np.float64(0.07066959114217883), 'random_strength': np.float64(0.9500619670508049)}
# Test accuracy: 0.8010

# %% [markdown]
# # 7. MLP (Neural Network) Classifier
#
# **Multi-Layer Perceptron (MLP)** is a feedforward neural network with one or more hidden layers. For tabular data, MLPs can capture complex non-linear relationships.
#
# ## Architecture Choices
#
# - **Hidden layers**: 1-3 layers with 16-128 neurons each
# - **Activation functions**: ReLU (most common) or Tanh
# - **Regularization**: L2 penalty (`alpha`) prevents overfitting
#
# ## Key Hyperparameters
#
# | Parameter | Description | Search Range |
# |-----------|-------------|--------------|
# | `hidden_layer_sizes` | Neurons per layer, e.g., (64, 32) | 1-3 layers, 16-128 neurons |
# | `activation` | Activation function | relu, tanh |
# | `alpha` | L2 regularization strength | 1e-6 to 1e-2 |
# | `learning_rate_init` | Initial learning rate | 1e-4 to 1e-2 |
# | `batch_size` | Samples per gradient update | 32, 64, 128, 256 |
#
# **Why StandardScaler is essential for MLPs:**
# Neural networks optimize via gradient descent, which is sensitive to feature scales. If one feature ranges 0-1 and another 0-10000, gradients will be dominated by the larger feature. Scaling ensures all features contribute equally to learning.
#
# **Custom samplers:** We define `HiddenLayerSampler` to randomly sample network architectures, and `LogUniform10` for logarithmic sampling of learning rates and regularization (common for parameters that span multiple orders of magnitude).

# %%
# custom samplers for hyperparameter search
class HiddenLayerSampler:
    """Samples network architectures: tuples of layer sizes (16-128 neurons, 1-3 layers)."""
    def __init__(self, sizes=(16, 32, 64, 128), min_layers=1, max_layers=3):
        self.sizes = np.array(sizes)
        self.min_layers = min_layers
        self.max_layers = max_layers

    def rvs(self, random_state=None):
        rng = check_random_state(random_state)
        n_layers = rng.randint(self.min_layers, self.max_layers + 1)
        return tuple(rng.choice(self.sizes, size=n_layers, replace=True))

class LogUniform10:
    """Samples 10^U(low_exp, high_exp) - uniform in log space."""
    def __init__(self, low_exp, high_exp):
        self.low_exp = low_exp
        self.high_exp = high_exp

    def rvs(self, random_state=None):
        rng = check_random_state(random_state)
        return float(10 ** rng.uniform(self.low_exp, self.high_exp))

# MLP pipeline: scaler + classifier
mlp_pipeline = Pipeline([
    ("scaler", StandardScaler(with_mean=False)),
    ("mlp", MLPClassifier(
        random_state=42,
        solver="adam",
        early_stopping=True,
        validation_fraction=0.1,
        n_iter_no_change=15,
        max_iter=400,
        tol=1e-4
    ))
])

# hyperparameter search space
param_distributions_mlp = {
    "mlp__hidden_layer_sizes": HiddenLayerSampler(sizes=(16, 32, 64, 128), min_layers=1, max_layers=3),
    "mlp__activation": ["relu", "tanh"],
    "mlp__alpha": LogUniform10(-6, -2),              # 1e-6 to 1e-2
    "mlp__learning_rate_init": LogUniform10(-4, -2), # 1e-4 to 1e-2
    "mlp__batch_size": [32, 64, 128, 256],
}

# randomized search (more iterations for neural networks due to higher variance)
search_mlp = RandomizedSearchCV(
    estimator=mlp_pipeline,
    param_distributions=param_distributions_mlp,
    n_iter=500,
    scoring="accuracy",
    cv=cv,
    n_jobs=-1,
    random_state=42,
    verbose=2,
    refit=True
)

search_mlp.fit(X_train, y_train)

print(f"\nBest CV accuracy: {search_mlp.best_score_:.4f}")
print(f"Best params: {search_mlp.best_params_}")

best_mlp = search_mlp.best_estimator_
mlp_test_acc = accuracy_score(y_test, best_mlp.predict(X_test))
print(f"Test accuracy: {mlp_test_acc:.4f}")
# Out:
# Fitting 5 folds for each of 500 candidates, totalling 2500 fits
# [CV] END mlp__activation=relu, mlp__alpha=2.5113061677389973e-06, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(128),), mlp__learning_rate_init=0.0001930783753654713; total time=   0.4s
# [CV] END mlp__activation=relu, mlp__alpha=0.0015352246941973478, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(128), np.int64(16), np.int64(16)), mlp__learning_rate_init=0.00020513382630874485; total time=   0.5s
# [CV] END mlp__activation=relu, mlp__alpha=2.5113061677389973e-06, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(128),), mlp__learning_rate_init=0.0001930783753654713; total time=   0.6s
# [CV] END mlp__activation=relu, mlp__alpha=2.5113061677389973e-06, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(128),), mlp__learning_rate_init=0.0001930783753654713; total time=   0.7s
# [CV] END mlp__activation=relu, mlp__alpha=0.0015352246941973478, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(128), np.int64(16), np.int64(16)), mlp__learning_rate_init=0.00020513382630874485; total time=   0.7s
# [CV] END mlp__activation=relu, mlp__alpha=0.0015352246941973478, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(128), np.int64(16), np.int64(16)), mlp__learning_rate_init=0.00020513382630874485; total time=   0.8s
# [CV] END mlp__activation=relu, mlp__alpha=2.5113061677389973e-06, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(128),), mlp__learning_rate_init=0.0001930783753654713; total time=   0.8s
# [CV] END mlp__activation=relu, mlp__alpha=2.5113061677389973e-06, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(128),), mlp__learning_rate_init=0.0001930783753654713; total time=   0.7s
# [CV] END mlp__activation=relu, mlp__alpha=0.0015352246941973478, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(128), np.int64(16), np.int64(16)), mlp__learning_rate_init=0.00020513382630874485; total time=   0.9s
# [CV] END mlp__activation=relu, mlp__alpha=1.2087541473056954e-06, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(32), np.int64(32)), mlp__learning_rate_init=0.0002310201887845293; total time=   0.6s
# [CV] END mlp__activation=relu, mlp__alpha=0.0015352246941973478, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(128), np.int64(16), np.int64(16)), mlp__learning_rate_init=0.00020513382630874485; total time=   1.4s
# [CV] END mlp__activation=relu, mlp__alpha=1.2087541473056954e-06, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(32), np.int64(32)), mlp__learning_rate_init=0.0002310201887845293; total time=   1.0s
# [CV] END mlp__activation=relu, mlp__alpha=1.2087541473056954e-06, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(32), np.int64(32)), mlp__learning_rate_init=0.0002310201887845293; total time=   0.9s
# [CV] END mlp__activation=relu, mlp__alpha=0.00029507066707905305, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(16), np.int64(128)), mlp__learning_rate_init=0.00011120513715710631; total time=   0.8s
# [CV] END mlp__activation=relu, mlp__alpha=1.2087541473056954e-06, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(32), np.int64(32)), mlp__learning_rate_init=0.0002310201887845293; total time=   1.0s
# [CV] END mlp__activation=relu, mlp__alpha=0.00029507066707905305, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(16), np.int64(128)), mlp__learning_rate_init=0.00011120513715710631; total time=   0.9s
# [CV] END mlp__activation=tanh, mlp__alpha=0.00011400863701127315, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(64),), mlp__learning_rate_init=0.005246634533625283; total time=   0.2s
# [CV] END mlp__activation=relu, mlp__alpha=0.00029507066707905305, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(16), np.int64(128)), mlp__learning_rate_init=0.00011120513715710631; total time=   1.2s
# [CV] END mlp__activation=tanh, mlp__alpha=0.00011400863701127315, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(64),), mlp__learning_rate_init=0.005246634533625283; total time=   0.2s
# [CV] END mlp__activation=relu, mlp__alpha=1.2087541473056954e-06, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(32), np.int64(32)), mlp__learning_rate_init=0.0002310201887845293; total time=   1.4s
# [CV] END mlp__activation=relu, mlp__alpha=0.0002801635158716258, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(32), np.int64(32), np.int64(64)), mlp__learning_rate_init=0.0017249321573178998; total time=   0.8s
# [CV] END mlp__activation=relu, mlp__alpha=0.0002801635158716258, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(32), np.int64(32), np.int64(64)), mlp__learning_rate_init=0.0017249321573178998; total time=   0.6s
# [CV] END mlp__activation=relu, mlp__alpha=0.0002801635158716258, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(32), np.int64(32), np.int64(64)), mlp__learning_rate_init=0.0017249321573178998; total time=   0.6s
# [CV] END mlp__activation=tanh, mlp__alpha=0.00011400863701127315, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(64),), mlp__learning_rate_init=0.005246634533625283; total time=   0.3s
# [CV] END mlp__activation=tanh, mlp__alpha=0.00011400863701127315, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(64),), mlp__learning_rate_init=0.005246634533625283; total time=   0.3s
# [CV] END mlp__activation=tanh, mlp__alpha=0.00011400863701127315, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(64),), mlp__learning_rate_init=0.005246634533625283; total time=   0.2s
# [CV] END mlp__activation=relu, mlp__alpha=0.0002801635158716258, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(32), np.int64(32), np.int64(64)), mlp__learning_rate_init=0.0017249321573178998; total time=   0.9s
# [CV] END mlp__activation=relu, mlp__alpha=0.00029507066707905305, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(16), np.int64(128)), mlp__learning_rate_init=0.00011120513715710631; total time=   1.5s
# [CV] END mlp__activation=relu, mlp__alpha=0.00029507066707905305, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(16), np.int64(128)), mlp__learning_rate_init=0.00011120513715710631; total time=   1.7s
# [CV] END mlp__activation=relu, mlp__alpha=4.809461967501567e-06, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(128), np.int64(16)), mlp__learning_rate_init=0.008536189862866826; total time=   0.4s
# [CV] END mlp__activation=relu, mlp__alpha=4.809461967501567e-06, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(128), np.int64(16)), mlp__learning_rate_init=0.008536189862866826; total time=   0.4s
# [CV] END mlp__activation=relu, mlp__alpha=0.0002801635158716258, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(32), np.int64(32), np.int64(64)), mlp__learning_rate_init=0.0017249321573178998; total time=   1.2s
# [CV] END mlp__activation=relu, mlp__alpha=4.809461967501567e-06, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(128), np.int64(16)), mlp__learning_rate_init=0.008536189862866826; total time=   0.4s
# [CV] END mlp__activation=tanh, mlp__alpha=3.4806953267852694e-05, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(32),), mlp__learning_rate_init=0.002335963502626158; total time=   0.5s
# [CV] END mlp__activation=relu, mlp__alpha=4.809461967501567e-06, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(128), np.int64(16)), mlp__learning_rate_init=0.008536189862866826; total time=   0.6s
# [CV] END mlp__activation=tanh, mlp__alpha=3.4806953267852694e-05, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(32),), mlp__learning_rate_init=0.002335963502626158; total time=   0.4s
# [CV] END mlp__activation=tanh, mlp__alpha=3.4806953267852694e-05, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(32),), mlp__learning_rate_init=0.002335963502626158; total time=   0.5s
# [CV] END mlp__activation=tanh, mlp__alpha=3.4806953267852694e-05, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(32),), mlp__learning_rate_init=0.002335963502626158; total time=   0.5s
# [CV] END mlp__activation=relu, mlp__alpha=4.809461967501567e-06, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(128), np.int64(16)), mlp__learning_rate_init=0.008536189862866826; total time=   1.0s
# [CV] END mlp__activation=tanh, mlp__alpha=3.4806953267852694e-05, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(32),), mlp__learning_rate_init=0.002335963502626158; total time=   0.6s
# [CV] END mlp__activation=relu, mlp__alpha=0.0005408216580718491, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(128),), mlp__learning_rate_init=0.00011715937392307056; total time=   0.6s
# [CV] END mlp__activation=relu, mlp__alpha=0.0005408216580718491, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(128),), mlp__learning_rate_init=0.00011715937392307056; total time=   0.9s
# [CV] END mlp__activation=relu, mlp__alpha=0.0005408216580718491, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(128),), mlp__learning_rate_init=0.00011715937392307056; total time=   1.2s
# [CV] END mlp__activation=relu, mlp__alpha=0.0005408216580718491, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(128),), mlp__learning_rate_init=0.00011715937392307056; total time=   1.0s
# [CV] END mlp__activation=tanh, mlp__alpha=3.6664218320637197e-05, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(32), np.int64(32)), mlp__learning_rate_init=0.00026054534945803986; total time=   1.0s
# [CV] END mlp__activation=relu, mlp__alpha=0.0005408216580718491, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(128),), mlp__learning_rate_init=0.00011715937392307056; total time=   1.2s
# [CV] END mlp__activation=tanh, mlp__alpha=3.6664218320637197e-05, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(32), np.int64(32)), mlp__learning_rate_init=0.00026054534945803986; total time=   1.1s
# [CV] END mlp__activation=tanh, mlp__alpha=3.6664218320637197e-05, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(32), np.int64(32)), mlp__learning_rate_init=0.00026054534945803986; total time=   1.1s
# [CV] END mlp__activation=tanh, mlp__alpha=3.6664218320637197e-05, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(32), np.int64(32)), mlp__learning_rate_init=0.00026054534945803986; total time=   1.4s
# [CV] END mlp__activation=tanh, mlp__alpha=5.488047000766047e-06, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(32), np.int64(128)), mlp__learning_rate_init=0.00756829206016762; total time=   0.6s
# [CV] END mlp__activation=tanh, mlp__alpha=5.488047000766047e-06, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(32), np.int64(128)), mlp__learning_rate_init=0.00756829206016762; total time=   0.7s
# [CV] END mlp__activation=tanh, mlp__alpha=3.6664218320637197e-05, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(32), np.int64(32)), mlp__learning_rate_init=0.00026054534945803986; total time=   1.5s
# [CV] END mlp__activation=tanh, mlp__alpha=5.488047000766047e-06, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(32), np.int64(128)), mlp__learning_rate_init=0.00756829206016762; total time=   1.3s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0050890352978407065, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(128), np.int64(32), np.int64(64)), mlp__learning_rate_init=0.001100698868558953; total time=   0.7s
# [CV] END mlp__activation=tanh, mlp__alpha=5.488047000766047e-06, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(32), np.int64(128)), mlp__learning_rate_init=0.00756829206016762; total time=   1.0s
# [CV] END mlp__activation=tanh, mlp__alpha=2.001342062287999e-05, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(32),), mlp__learning_rate_init=0.0012005610926192104; total time=   0.2s
# [CV] END mlp__activation=tanh, mlp__alpha=2.001342062287999e-05, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(32),), mlp__learning_rate_init=0.0012005610926192104; total time=   0.2s
# [CV] END mlp__activation=tanh, mlp__alpha=2.001342062287999e-05, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(32),), mlp__learning_rate_init=0.0012005610926192104; total time=   0.2s
# [CV] END mlp__activation=tanh, mlp__alpha=2.001342062287999e-05, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(32),), mlp__learning_rate_init=0.0012005610926192104; total time=   0.3s
# [CV] END mlp__activation=tanh, mlp__alpha=5.488047000766047e-06, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(32), np.int64(128)), mlp__learning_rate_init=0.00756829206016762; total time=   1.2s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0050890352978407065, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(128), np.int64(32), np.int64(64)), mlp__learning_rate_init=0.001100698868558953; total time=   0.7s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0050890352978407065, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(128), np.int64(32), np.int64(64)), mlp__learning_rate_init=0.001100698868558953; total time=   1.1s
# [CV] END mlp__activation=tanh, mlp__alpha=2.673088310781672e-05, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(16),), mlp__learning_rate_init=0.00039133348581043724; total time=   0.3s
# [CV] END mlp__activation=tanh, mlp__alpha=2.673088310781672e-05, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(16),), mlp__learning_rate_init=0.00039133348581043724; total time=   0.4s
# [CV] END mlp__activation=tanh, mlp__alpha=2.673088310781672e-05, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(16),), mlp__learning_rate_init=0.00039133348581043724; total time=   0.4s
# [CV] END mlp__activation=tanh, mlp__alpha=2.673088310781672e-05, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(16),), mlp__learning_rate_init=0.00039133348581043724; total time=   0.2s
# [CV] END mlp__activation=tanh, mlp__alpha=2.001342062287999e-05, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(32),), mlp__learning_rate_init=0.0012005610926192104; total time=   0.5s
# [CV] END mlp__activation=tanh, mlp__alpha=2.673088310781672e-05, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(16),), mlp__learning_rate_init=0.00039133348581043724; total time=   0.4s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0050890352978407065, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(128), np.int64(32), np.int64(64)), mlp__learning_rate_init=0.001100698868558953; total time=   1.2s
# [CV] END mlp__activation=relu, mlp__alpha=1.9870215385428602e-06, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(128),), mlp__learning_rate_init=0.000616258661535373; total time=   0.4s
# [CV] END mlp__activation=relu, mlp__alpha=1.9870215385428602e-06, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(128),), mlp__learning_rate_init=0.000616258661535373; total time=   0.4s
# [CV] END mlp__activation=relu, mlp__alpha=1.9870215385428602e-06, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(128),), mlp__learning_rate_init=0.000616258661535373; total time=   0.4s
# [CV] END mlp__activation=relu, mlp__alpha=1.9870215385428602e-06, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(128),), mlp__learning_rate_init=0.000616258661535373; total time=   0.5s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0050890352978407065, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(128), np.int64(32), np.int64(64)), mlp__learning_rate_init=0.001100698868558953; total time=   1.5s
# [CV] END mlp__activation=tanh, mlp__alpha=1.0521761868451128e-06, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(16), np.int64(128), np.int64(64)), mlp__learning_rate_init=0.003804968634158323; total time=   0.6s
# [CV] END mlp__activation=relu, mlp__alpha=1.9870215385428602e-06, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(128),), mlp__learning_rate_init=0.000616258661535373; total time=   0.9s
# [CV] END mlp__activation=tanh, mlp__alpha=1.0521761868451128e-06, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(16), np.int64(128), np.int64(64)), mlp__learning_rate_init=0.003804968634158323; total time=   0.7s
# [CV] END mlp__activation=tanh, mlp__alpha=1.0521761868451128e-06, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(16), np.int64(128), np.int64(64)), mlp__learning_rate_init=0.003804968634158323; total time=   0.9s
# [CV] END mlp__activation=relu, mlp__alpha=1.9777828512462736e-06, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(16), np.int64(128)), mlp__learning_rate_init=0.005323617594751501; total time=   0.7s
# [CV] END mlp__activation=relu, mlp__alpha=1.9777828512462736e-06, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(16), np.int64(128)), mlp__learning_rate_init=0.005323617594751501; total time=   0.7s
# [CV] END mlp__activation=relu, mlp__alpha=1.9777828512462736e-06, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(16), np.int64(128)), mlp__learning_rate_init=0.005323617594751501; total time=   0.9s
# [CV] END mlp__activation=tanh, mlp__alpha=1.0521761868451128e-06, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(16), np.int64(128), np.int64(64)), mlp__learning_rate_init=0.003804968634158323; total time=   1.1s
# [CV] END mlp__activation=relu, mlp__alpha=1.9777828512462736e-06, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(16), np.int64(128)), mlp__learning_rate_init=0.005323617594751501; total time=   1.1s
# [CV] END mlp__activation=tanh, mlp__alpha=1.0521761868451128e-06, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(16), np.int64(128), np.int64(64)), mlp__learning_rate_init=0.003804968634158323; total time=   1.2s
# [CV] END mlp__activation=relu, mlp__alpha=1.9777828512462736e-06, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(16), np.int64(128)), mlp__learning_rate_init=0.005323617594751501; total time=   0.9s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0003550012525851159, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(16), np.int64(64), np.int64(16)), mlp__learning_rate_init=0.008778578373294493; total time=   0.4s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0003550012525851159, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(16), np.int64(64), np.int64(16)), mlp__learning_rate_init=0.008778578373294493; total time=   0.4s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0003550012525851159, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(16), np.int64(64), np.int64(16)), mlp__learning_rate_init=0.008778578373294493; total time=   0.7s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0003550012525851159, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(16), np.int64(64), np.int64(16)), mlp__learning_rate_init=0.008778578373294493; total time=   0.7s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0003550012525851159, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(16), np.int64(64), np.int64(16)), mlp__learning_rate_init=0.008778578373294493; total time=   0.5s
# [CV] END mlp__activation=tanh, mlp__alpha=6.277730916958047e-05, mlp__batch_size=32, mlp__hidden_layer_sizes=(np.int64(64), np.int64(32), np.int64(128)), mlp__learning_rate_init=0.002147062631022879; total time=   1.4s
# [CV] END mlp__activation=tanh, mlp__alpha=6.277730916958047e-05, mlp__batch_size=32, mlp__hidden_layer_sizes=(np.int64(64), np.int64(32), np.int64(128)), mlp__learning_rate_init=0.002147062631022879; total time=   2.1s
# [CV] END mlp__activation=relu, mlp__alpha=0.0011044350847124681, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(64), np.int64(32), np.int64(64)), mlp__learning_rate_init=0.00012046674587990318; total time=   1.1s
# [CV] END mlp__activation=relu, mlp__alpha=0.0011044350847124681, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(64), np.int64(32), np.int64(64)), mlp__learning_rate_init=0.00012046674587990318; total time=   1.1s
# [CV] END mlp__activation=tanh, mlp__alpha=6.277730916958047e-05, mlp__batch_size=32, mlp__hidden_layer_sizes=(np.int64(64), np.int64(32), np.int64(128)), mlp__learning_rate_init=0.002147062631022879; total time=   1.9s
# [CV] END mlp__activation=relu, mlp__alpha=0.0011044350847124681, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(64), np.int64(32), np.int64(64)), mlp__learning_rate_init=0.00012046674587990318; total time=   1.2s
# [CV] END mlp__activation=tanh, mlp__alpha=6.277730916958047e-05, mlp__batch_size=32, mlp__hidden_layer_sizes=(np.int64(64), np.int64(32), np.int64(128)), mlp__learning_rate_init=0.002147062631022879; total time=   2.4s
# [CV] END mlp__activation=relu, mlp__alpha=5.1305517605898265e-05, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(64),), mlp__learning_rate_init=0.00011557352816269858; total time=   0.5s
# [CV] END mlp__activation=relu, mlp__alpha=5.1305517605898265e-05, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(64),), mlp__learning_rate_init=0.00011557352816269858; total time=   0.7s
# [CV] END mlp__activation=relu, mlp__alpha=0.0011044350847124681, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(64), np.int64(32), np.int64(64)), mlp__learning_rate_init=0.00012046674587990318; total time=   1.7s
# [CV] END mlp__activation=relu, mlp__alpha=5.1305517605898265e-05, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(64),), mlp__learning_rate_init=0.00011557352816269858; total time=   1.3s
# [CV] END mlp__activation=tanh, mlp__alpha=6.277730916958047e-05, mlp__batch_size=32, mlp__hidden_layer_sizes=(np.int64(64), np.int64(32), np.int64(128)), mlp__learning_rate_init=0.002147062631022879; total time=   2.5s
# [CV] END mlp__activation=relu, mlp__alpha=0.0011044350847124681, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(64), np.int64(32), np.int64(64)), mlp__learning_rate_init=0.00012046674587990318; total time=   1.7s
# [CV] END mlp__activation=relu, mlp__alpha=0.0010524574681335626, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(128),), mlp__learning_rate_init=0.0015766341637993278; total time=   0.3s
# [CV] END mlp__activation=relu, mlp__alpha=0.0010524574681335626, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(128),), mlp__learning_rate_init=0.0015766341637993278; total time=   0.2s
# [CV] END mlp__activation=relu, mlp__alpha=0.0010524574681335626, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(128),), mlp__learning_rate_init=0.0015766341637993278; total time=   0.5s
# [CV] END mlp__activation=relu, mlp__alpha=7.970414230898698e-05, mlp__batch_size=32, mlp__hidden_layer_sizes=(np.int64(16), np.int64(64)), mlp__learning_rate_init=0.001617464503634303; total time=   0.7s
# [CV] END mlp__activation=relu, mlp__alpha=5.1305517605898265e-05, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(64),), mlp__learning_rate_init=0.00011557352816269858; total time=   1.3s
# [CV] END mlp__activation=relu, mlp__alpha=5.1305517605898265e-05, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(64),), mlp__learning_rate_init=0.00011557352816269858; total time=   1.2s
# [CV] END mlp__activation=relu, mlp__alpha=4.4145368764944785e-06, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(16), np.int64(32)), mlp__learning_rate_init=0.0018484491720988623; total time=   0.3s
# [CV] END mlp__activation=relu, mlp__alpha=0.0010524574681335626, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(128),), mlp__learning_rate_init=0.0015766341637993278; total time=   0.5s
# [CV] END mlp__activation=relu, mlp__alpha=0.0010524574681335626, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(128),), mlp__learning_rate_init=0.0015766341637993278; total time=   0.4s
# [CV] END mlp__activation=relu, mlp__alpha=7.970414230898698e-05, mlp__batch_size=32, mlp__hidden_layer_sizes=(np.int64(16), np.int64(64)), mlp__learning_rate_init=0.001617464503634303; total time=   1.3s
# [CV] END mlp__activation=relu, mlp__alpha=7.970414230898698e-05, mlp__batch_size=32, mlp__hidden_layer_sizes=(np.int64(16), np.int64(64)), mlp__learning_rate_init=0.001617464503634303; total time=   1.1s
# [CV] END mlp__activation=relu, mlp__alpha=4.4145368764944785e-06, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(16), np.int64(32)), mlp__learning_rate_init=0.0018484491720988623; total time=   0.4s
# [CV] END mlp__activation=relu, mlp__alpha=7.970414230898698e-05, mlp__batch_size=32, mlp__hidden_layer_sizes=(np.int64(16), np.int64(64)), mlp__learning_rate_init=0.001617464503634303; total time=   1.6s
# [CV] END mlp__activation=tanh, mlp__alpha=6.700979385989826e-05, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(32), np.int64(64)), mlp__learning_rate_init=0.000445338294938445; total time=   0.5s
# [CV] END mlp__activation=tanh, mlp__alpha=6.700979385989826e-05, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(32), np.int64(64)), mlp__learning_rate_init=0.000445338294938445; total time=   0.5s
# [CV] END mlp__activation=relu, mlp__alpha=4.4145368764944785e-06, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(16), np.int64(32)), mlp__learning_rate_init=0.0018484491720988623; total time=   0.6s
# [CV] END mlp__activation=tanh, mlp__alpha=6.700979385989826e-05, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(32), np.int64(64)), mlp__learning_rate_init=0.000445338294938445; total time=   0.4s
# [CV] END mlp__activation=tanh, mlp__alpha=6.700979385989826e-05, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(32), np.int64(64)), mlp__learning_rate_init=0.000445338294938445; total time=   0.4s
# [CV] END mlp__activation=relu, mlp__alpha=4.4145368764944785e-06, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(16), np.int64(32)), mlp__learning_rate_init=0.0018484491720988623; total time=   1.0s
# [CV] END mlp__activation=tanh, mlp__alpha=6.700979385989826e-05, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(32), np.int64(64)), mlp__learning_rate_init=0.000445338294938445; total time=   0.8s
# [CV] END mlp__activation=relu, mlp__alpha=0.003840300419098852, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(16), np.int64(16)), mlp__learning_rate_init=0.00028567374298471885; total time=   0.4s
# [CV] END mlp__activation=relu, mlp__alpha=7.970414230898698e-05, mlp__batch_size=32, mlp__hidden_layer_sizes=(np.int64(16), np.int64(64)), mlp__learning_rate_init=0.001617464503634303; total time=   1.8s
# [CV] END mlp__activation=relu, mlp__alpha=4.4145368764944785e-06, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(16), np.int64(32)), mlp__learning_rate_init=0.0018484491720988623; total time=   0.9s
# [CV] END mlp__activation=relu, mlp__alpha=0.003840300419098852, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(16), np.int64(16)), mlp__learning_rate_init=0.00028567374298471885; total time=   0.5s
# [CV] END mlp__activation=relu, mlp__alpha=0.003840300419098852, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(16), np.int64(16)), mlp__learning_rate_init=0.00028567374298471885; total time=   0.6s
# [CV] END mlp__activation=relu, mlp__alpha=0.003840300419098852, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(16), np.int64(16)), mlp__learning_rate_init=0.00028567374298471885; total time=   0.6s
# [CV] END mlp__activation=relu, mlp__alpha=0.003840300419098852, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(16), np.int64(16)), mlp__learning_rate_init=0.00028567374298471885; total time=   0.6s
# [CV] END mlp__activation=tanh, mlp__alpha=1.0048043533223178e-06, mlp__batch_size=32, mlp__hidden_layer_sizes=(np.int64(64),), mlp__learning_rate_init=0.0001032533761648204; total time=   0.6s
# [CV] END mlp__activation=tanh, mlp__alpha=0.00013688557276310287, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(16),), mlp__learning_rate_init=0.00017367237151593167; total time=   0.5s
# [CV] END mlp__activation=tanh, mlp__alpha=1.0048043533223178e-06, mlp__batch_size=32, mlp__hidden_layer_sizes=(np.int64(64),), mlp__learning_rate_init=0.0001032533761648204; total time=   0.7s
# [CV] END mlp__activation=tanh, mlp__alpha=0.00013688557276310287, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(16),), mlp__learning_rate_init=0.00017367237151593167; total time=   0.5s
# [CV] END mlp__activation=tanh, mlp__alpha=0.00013688557276310287, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(16),), mlp__learning_rate_init=0.00017367237151593167; total time=   0.8s
# [CV] END mlp__activation=tanh, mlp__alpha=1.0048043533223178e-06, mlp__batch_size=32, mlp__hidden_layer_sizes=(np.int64(64),), mlp__learning_rate_init=0.0001032533761648204; total time=   1.1s
# [CV] END mlp__activation=tanh, mlp__alpha=0.00013688557276310287, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(16),), mlp__learning_rate_init=0.00017367237151593167; total time=   0.7s
# [CV] END mlp__activation=tanh, mlp__alpha=1.0048043533223178e-06, mlp__batch_size=32, mlp__hidden_layer_sizes=(np.int64(64),), mlp__learning_rate_init=0.0001032533761648204; total time=   1.8s
# [CV] END mlp__activation=tanh, mlp__alpha=9.473317412345247e-06, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(128), np.int64(128)), mlp__learning_rate_init=0.001306784588595592; total time=   1.1s
# [CV] END mlp__activation=tanh, mlp__alpha=1.0048043533223178e-06, mlp__batch_size=32, mlp__hidden_layer_sizes=(np.int64(64),), mlp__learning_rate_init=0.0001032533761648204; total time=   1.8s
# [CV] END mlp__activation=tanh, mlp__alpha=9.473317412345247e-06, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(128), np.int64(128)), mlp__learning_rate_init=0.001306784588595592; total time=   1.2s
# [CV] END mlp__activation=tanh, mlp__alpha=0.00013688557276310287, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(16),), mlp__learning_rate_init=0.00017367237151593167; total time=   1.6s
# [CV] END mlp__activation=tanh, mlp__alpha=9.473317412345247e-06, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(128), np.int64(128)), mlp__learning_rate_init=0.001306784588595592; total time=   1.8s
# [CV] END mlp__activation=tanh, mlp__alpha=9.473317412345247e-06, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(128), np.int64(128)), mlp__learning_rate_init=0.001306784588595592; total time=   2.1s
# [CV] END mlp__activation=tanh, mlp__alpha=2.847858516856296e-05, mlp__batch_size=32, mlp__hidden_layer_sizes=(np.int64(128), np.int64(128)), mlp__learning_rate_init=0.00031883397351001867; total time=   1.7s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0007064515131755318, mlp__batch_size=32, mlp__hidden_layer_sizes=(np.int64(128),), mlp__learning_rate_init=0.00011851515660043105; total time=   1.2s
# [CV] END mlp__activation=tanh, mlp__alpha=9.473317412345247e-06, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(128), np.int64(128)), mlp__learning_rate_init=0.001306784588595592; total time=   2.3s
# [CV] END mlp__activation=relu, mlp__alpha=0.008062316132568963, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(64), np.int64(16)), mlp__learning_rate_init=0.0004899395467149151; total time=   0.4s
# [CV] END mlp__activation=relu, mlp__alpha=0.008062316132568963, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(64), np.int64(16)), mlp__learning_rate_init=0.0004899395467149151; total time=   0.4s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0007064515131755318, mlp__batch_size=32, mlp__hidden_layer_sizes=(np.int64(128),), mlp__learning_rate_init=0.00011851515660043105; total time=   1.2s
# [CV] END mlp__activation=tanh, mlp__alpha=2.847858516856296e-05, mlp__batch_size=32, mlp__hidden_layer_sizes=(np.int64(128), np.int64(128)), mlp__learning_rate_init=0.00031883397351001867; total time=   2.8s
# [CV] END mlp__activation=tanh, mlp__alpha=2.847858516856296e-05, mlp__batch_size=32, mlp__hidden_layer_sizes=(np.int64(128), np.int64(128)), mlp__learning_rate_init=0.00031883397351001867; total time=   2.0s
# [CV] END mlp__activation=relu, mlp__alpha=0.008062316132568963, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(64), np.int64(16)), mlp__learning_rate_init=0.0004899395467149151; total time=   0.3s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0007064515131755318, mlp__batch_size=32, mlp__hidden_layer_sizes=(np.int64(128),), mlp__learning_rate_init=0.00011851515660043105; total time=   1.1s
# [CV] END mlp__activation=relu, mlp__alpha=0.008062316132568963, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(64), np.int64(16)), mlp__learning_rate_init=0.0004899395467149151; total time=   0.5s
# [CV] END mlp__activation=relu, mlp__alpha=9.083381663660572e-06, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(128),), mlp__learning_rate_init=0.0007862602663320716; total time=   0.6s
# [CV] END mlp__activation=relu, mlp__alpha=0.008062316132568963, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(64), np.int64(16)), mlp__learning_rate_init=0.0004899395467149151; total time=   0.8s
# [CV] END mlp__activation=relu, mlp__alpha=9.083381663660572e-06, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(128),), mlp__learning_rate_init=0.0007862602663320716; total time=   0.7s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0007064515131755318, mlp__batch_size=32, mlp__hidden_layer_sizes=(np.int64(128),), mlp__learning_rate_init=0.00011851515660043105; total time=   1.7s
# [CV] END mlp__activation=relu, mlp__alpha=9.083381663660572e-06, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(128),), mlp__learning_rate_init=0.0007862602663320716; total time=   0.7s
# [CV] END mlp__activation=relu, mlp__alpha=9.083381663660572e-06, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(128),), mlp__learning_rate_init=0.0007862602663320716; total time=   0.9s
# [CV] END mlp__activation=tanh, mlp__alpha=2.847858516856296e-05, mlp__batch_size=32, mlp__hidden_layer_sizes=(np.int64(128), np.int64(128)), mlp__learning_rate_init=0.00031883397351001867; total time=   3.0s
# [CV] END mlp__activation=relu, mlp__alpha=9.083381663660572e-06, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(128),), mlp__learning_rate_init=0.0007862602663320716; total time=   0.6s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0007064515131755318, mlp__batch_size=32, mlp__hidden_layer_sizes=(np.int64(128),), mlp__learning_rate_init=0.00011851515660043105; total time=   2.9s
# [CV] END mlp__activation=tanh, mlp__alpha=2.958915282095305e-05, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(32), np.int64(32)), mlp__learning_rate_init=0.001179096548677631; total time=   0.3s
# [CV] END mlp__activation=tanh, mlp__alpha=2.958915282095305e-05, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(32), np.int64(32)), mlp__learning_rate_init=0.001179096548677631; total time=   0.4s
# [CV] END mlp__activation=tanh, mlp__alpha=2.958915282095305e-05, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(32), np.int64(32)), mlp__learning_rate_init=0.001179096548677631; total time=   0.5s
# [CV] END mlp__activation=tanh, mlp__alpha=2.958915282095305e-05, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(32), np.int64(32)), mlp__learning_rate_init=0.001179096548677631; total time=   0.4s
# [CV] END mlp__activation=tanh, mlp__alpha=9.294394155644998e-06, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(64), np.int64(128), np.int64(64)), mlp__learning_rate_init=0.0003050140722244878; total time=   1.0s
# [CV] END mlp__activation=tanh, mlp__alpha=2.958915282095305e-05, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(32), np.int64(32)), mlp__learning_rate_init=0.001179096548677631; total time=   0.9s
# [CV] END mlp__activation=tanh, mlp__alpha=9.294394155644998e-06, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(64), np.int64(128), np.int64(64)), mlp__learning_rate_init=0.0003050140722244878; total time=   1.3s
# [CV] END mlp__activation=tanh, mlp__alpha=9.294394155644998e-06, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(64), np.int64(128), np.int64(64)), mlp__learning_rate_init=0.0003050140722244878; total time=   1.2s
# [CV] END mlp__activation=tanh, mlp__alpha=9.294394155644998e-06, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(64), np.int64(128), np.int64(64)), mlp__learning_rate_init=0.0003050140722244878; total time=   1.4s
# [CV] END mlp__activation=tanh, mlp__alpha=9.294394155644998e-06, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(64), np.int64(128), np.int64(64)), mlp__learning_rate_init=0.0003050140722244878; total time=   1.4s
# [CV] END mlp__activation=tanh, mlp__alpha=2.847858516856296e-05, mlp__batch_size=32, mlp__hidden_layer_sizes=(np.int64(128), np.int64(128)), mlp__learning_rate_init=0.00031883397351001867; total time=   4.5s
# [CV] END mlp__activation=tanh, mlp__alpha=0.000513165495514832, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(64), np.int64(64)), mlp__learning_rate_init=0.00028378638146176247; total time=   0.6s
# [CV] END mlp__activation=tanh, mlp__alpha=0.000513165495514832, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(64), np.int64(64)), mlp__learning_rate_init=0.00028378638146176247; total time=   0.7s
# [CV] END mlp__activation=tanh, mlp__alpha=0.000513165495514832, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(64), np.int64(64)), mlp__learning_rate_init=0.00028378638146176247; total time=   0.8s
# [CV] END mlp__activation=tanh, mlp__alpha=0.000513165495514832, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(64), np.int64(64)), mlp__learning_rate_init=0.00028378638146176247; total time=   0.8s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0015609194777360274, mlp__batch_size=32, mlp__hidden_layer_sizes=(np.int64(32), np.int64(128), np.int64(16)), mlp__learning_rate_init=0.005208559259379701; total time=   1.3s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0015609194777360274, mlp__batch_size=32, mlp__hidden_layer_sizes=(np.int64(32), np.int64(128), np.int64(16)), mlp__learning_rate_init=0.005208559259379701; total time=   1.1s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0015609194777360274, mlp__batch_size=32, mlp__hidden_layer_sizes=(np.int64(32), np.int64(128), np.int64(16)), mlp__learning_rate_init=0.005208559259379701; total time=   1.7s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0015609194777360274, mlp__batch_size=32, mlp__hidden_layer_sizes=(np.int64(32), np.int64(128), np.int64(16)), mlp__learning_rate_init=0.005208559259379701; total time=   1.4s
# [CV] END mlp__activation=tanh, mlp__alpha=0.000513165495514832, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(64), np.int64(64)), mlp__learning_rate_init=0.00028378638146176247; total time=   0.8s
# [CV] END mlp__activation=tanh, mlp__alpha=2.424969074088043e-06, mlp__batch_size=32, mlp__hidden_layer_sizes=(np.int64(128),), mlp__learning_rate_init=0.0005935682912014684; total time=   0.6s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0022430575873653514, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(16),), mlp__learning_rate_init=0.0002619046694650946; total time=   0.5s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0022430575873653514, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(16),), mlp__learning_rate_init=0.0002619046694650946; total time=   0.5s
# [CV] END mlp__activation=tanh, mlp__alpha=2.424969074088043e-06, mlp__batch_size=32, mlp__hidden_layer_sizes=(np.int64(128),), mlp__learning_rate_init=0.0005935682912014684; total time=   0.9s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0022430575873653514, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(16),), mlp__learning_rate_init=0.0002619046694650946; total time=   0.4s
# [CV] END mlp__activation=tanh, mlp__alpha=2.424969074088043e-06, mlp__batch_size=32, mlp__hidden_layer_sizes=(np.int64(128),), mlp__learning_rate_init=0.0005935682912014684; total time=   1.1s
# [CV] END mlp__activation=tanh, mlp__alpha=2.424969074088043e-06, mlp__batch_size=32, mlp__hidden_layer_sizes=(np.int64(128),), mlp__learning_rate_init=0.0005935682912014684; total time=   1.1s
# [CV] END mlp__activation=tanh, mlp__alpha=2.424969074088043e-06, mlp__batch_size=32, mlp__hidden_layer_sizes=(np.int64(128),), mlp__learning_rate_init=0.0005935682912014684; total time=   1.1s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0022430575873653514, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(16),), mlp__learning_rate_init=0.0002619046694650946; total time=   0.6s
# [CV] END mlp__activation=relu, mlp__alpha=0.0032311521854410954, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(128), np.int64(128), np.int64(32)), mlp__learning_rate_init=0.009211634266628618; total time=   0.8s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0022430575873653514, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(16),), mlp__learning_rate_init=0.0002619046694650946; total time=   1.0s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0015609194777360274, mlp__batch_size=32, mlp__hidden_layer_sizes=(np.int64(32), np.int64(128), np.int64(16)), mlp__learning_rate_init=0.005208559259379701; total time=   3.0s
# [CV] END mlp__activation=relu, mlp__alpha=0.0032311521854410954, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(128), np.int64(128), np.int64(32)), mlp__learning_rate_init=0.009211634266628618; total time=   1.1s
# [CV] END mlp__activation=relu, mlp__alpha=0.0032311521854410954, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(128), np.int64(128), np.int64(32)), mlp__learning_rate_init=0.009211634266628618; total time=   1.0s
# [CV] END mlp__activation=tanh, mlp__alpha=0.00013140210226207373, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(128),), mlp__learning_rate_init=0.008527833305781808; total time=   0.7s
# [CV] END mlp__activation=relu, mlp__alpha=0.0032311521854410954, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(128), np.int64(128), np.int64(32)), mlp__learning_rate_init=0.009211634266628618; total time=   1.1s
# [CV] END mlp__activation=relu, mlp__alpha=0.003996430167694252, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(16), np.int64(16), np.int64(64)), mlp__learning_rate_init=0.00251602910093301; total time=   0.4s
# [CV] END mlp__activation=tanh, mlp__alpha=0.00013140210226207373, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(128),), mlp__learning_rate_init=0.008527833305781808; total time=   0.5s
# [CV] END mlp__activation=tanh, mlp__alpha=0.00013140210226207373, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(128),), mlp__learning_rate_init=0.008527833305781808; total time=   0.8s
# [CV] END mlp__activation=relu, mlp__alpha=0.0032311521854410954, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(128), np.int64(128), np.int64(32)), mlp__learning_rate_init=0.009211634266628618; total time=   1.1s
# [CV] END mlp__activation=relu, mlp__alpha=0.003996430167694252, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(16), np.int64(16), np.int64(64)), mlp__learning_rate_init=0.00251602910093301; total time=   0.4s
# [CV] END mlp__activation=tanh, mlp__alpha=0.00013140210226207373, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(128),), mlp__learning_rate_init=0.008527833305781808; total time=   1.1s
# [CV] END mlp__activation=relu, mlp__alpha=0.003996430167694252, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(16), np.int64(16), np.int64(64)), mlp__learning_rate_init=0.00251602910093301; total time=   0.4s
# [CV] END mlp__activation=tanh, mlp__alpha=0.00013140210226207373, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(128),), mlp__learning_rate_init=0.008527833305781808; total time=   0.8s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0038765111709116286, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(128), np.int64(16)), mlp__learning_rate_init=0.0019233720128877165; total time=   0.5s
# [CV] END mlp__activation=relu, mlp__alpha=0.003996430167694252, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(16), np.int64(16), np.int64(64)), mlp__learning_rate_init=0.00251602910093301; total time=   0.6s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0038765111709116286, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(128), np.int64(16)), mlp__learning_rate_init=0.0019233720128877165; total time=   0.5s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0038765111709116286, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(128), np.int64(16)), mlp__learning_rate_init=0.0019233720128877165; total time=   0.6s
# [CV] END mlp__activation=relu, mlp__alpha=0.003996430167694252, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(16), np.int64(16), np.int64(64)), mlp__learning_rate_init=0.00251602910093301; total time=   1.0s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0038765111709116286, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(128), np.int64(16)), mlp__learning_rate_init=0.0019233720128877165; total time=   0.8s
# [CV] END mlp__activation=relu, mlp__alpha=0.005527642876529965, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(128), np.int64(128)), mlp__learning_rate_init=0.0014500174972770096; total time=   0.5s
# [CV] END mlp__activation=relu, mlp__alpha=0.005527642876529965, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(128), np.int64(128)), mlp__learning_rate_init=0.0014500174972770096; total time=   0.6s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0038765111709116286, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(128), np.int64(16)), mlp__learning_rate_init=0.0019233720128877165; total time=   0.7s
# [CV] END mlp__activation=relu, mlp__alpha=0.005527642876529965, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(128), np.int64(128)), mlp__learning_rate_init=0.0014500174972770096; total time=   0.7s
# [CV] END mlp__activation=tanh, mlp__alpha=2.546162816127693e-06, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(16),), mlp__learning_rate_init=0.0003696936146274881; total time=   0.4s
# [CV] END mlp__activation=relu, mlp__alpha=0.005527642876529965, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(128), np.int64(128)), mlp__learning_rate_init=0.0014500174972770096; total time=   0.5s
# [CV] END mlp__activation=relu, mlp__alpha=0.005527642876529965, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(128), np.int64(128)), mlp__learning_rate_init=0.0014500174972770096; total time=   0.6s
# [CV] END mlp__activation=tanh, mlp__alpha=2.546162816127693e-06, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(16),), mlp__learning_rate_init=0.0003696936146274881; total time=   0.5s
# [CV] END mlp__activation=tanh, mlp__alpha=2.546162816127693e-06, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(16),), mlp__learning_rate_init=0.0003696936146274881; total time=   0.5s
# [CV] END mlp__activation=tanh, mlp__alpha=2.546162816127693e-06, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(16),), mlp__learning_rate_init=0.0003696936146274881; total time=   0.5s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001566517163094646, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(128), np.int64(16), np.int64(16)), mlp__learning_rate_init=0.00022482805601745348; total time=   0.6s
# [CV] END mlp__activation=tanh, mlp__alpha=2.546162816127693e-06, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(16),), mlp__learning_rate_init=0.0003696936146274881; total time=   0.7s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001566517163094646, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(128), np.int64(16), np.int64(16)), mlp__learning_rate_init=0.00022482805601745348; total time=   0.9s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001566517163094646, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(128), np.int64(16), np.int64(16)), mlp__learning_rate_init=0.00022482805601745348; total time=   0.7s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001566517163094646, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(128), np.int64(16), np.int64(16)), mlp__learning_rate_init=0.00022482805601745348; total time=   0.8s
# [CV] END mlp__activation=tanh, mlp__alpha=8.891936446296248e-06, mlp__batch_size=32, mlp__hidden_layer_sizes=(np.int64(64), np.int64(16), np.int64(128)), mlp__learning_rate_init=0.0013696739838480049; total time=   1.0s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001566517163094646, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(128), np.int64(16), np.int64(16)), mlp__learning_rate_init=0.00022482805601745348; total time=   1.1s
# [CV] END mlp__activation=tanh, mlp__alpha=0.00010845668034236332, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(32), np.int64(32), np.int64(32)), mlp__learning_rate_init=0.008831228248242529; total time=   0.9s
# [CV] END mlp__activation=relu, mlp__alpha=8.850516413727306e-05, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(64), np.int64(32), np.int64(16)), mlp__learning_rate_init=0.0010122183035228768; total time=   0.3s
# ...
# [CV] END mlp__activation=relu, mlp__alpha=3.5489109270358786e-06, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(128), np.int64(16)), mlp__learning_rate_init=0.0002193632253934874; total time=   1.2s
# [CV] END mlp__activation=relu, mlp__alpha=3.5489109270358786e-06, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(128), np.int64(16)), mlp__learning_rate_init=0.0002193632253934874; total time=   0.6s
# [CV] END mlp__activation=relu, mlp__alpha=0.00033514304590157886, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(16),), mlp__learning_rate_init=0.0019020026704296526; total time=   0.2s
# [CV] END mlp__activation=relu, mlp__alpha=3.5489109270358786e-06, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(128), np.int64(16)), mlp__learning_rate_init=0.0002193632253934874; total time=   0.6s
# [CV] END mlp__activation=relu, mlp__alpha=0.00033514304590157886, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(16),), mlp__learning_rate_init=0.0019020026704296526; total time=   0.2s
# [CV] END mlp__activation=relu, mlp__alpha=3.5489109270358786e-06, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(128), np.int64(16)), mlp__learning_rate_init=0.0002193632253934874; total time=   0.6s
# [CV] END mlp__activation=relu, mlp__alpha=0.00033514304590157886, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(16),), mlp__learning_rate_init=0.0019020026704296526; total time=   0.3s
# [CV] END mlp__activation=relu, mlp__alpha=0.00011206115907967532, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(128), np.int64(16)), mlp__learning_rate_init=0.00874042223051729; total time=   0.2s
# [CV] END mlp__activation=relu, mlp__alpha=0.00011206115907967532, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(128), np.int64(16)), mlp__learning_rate_init=0.00874042223051729; total time=   0.3s
# [CV] END mlp__activation=relu, mlp__alpha=0.00011206115907967532, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(128), np.int64(16)), mlp__learning_rate_init=0.00874042223051729; total time=   0.3s
# [CV] END mlp__activation=relu, mlp__alpha=1.2605725132379146e-06, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(128), np.int64(128), np.int64(32)), mlp__learning_rate_init=0.0007399321907555844; total time=   2.3s
# [CV] END mlp__activation=relu, mlp__alpha=0.00011206115907967532, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(128), np.int64(16)), mlp__learning_rate_init=0.00874042223051729; total time=   0.4s
# [CV] END mlp__activation=relu, mlp__alpha=0.00011206115907967532, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(128), np.int64(16)), mlp__learning_rate_init=0.00874042223051729; total time=   0.5s
# [CV] END mlp__activation=relu, mlp__alpha=3.5489109270358786e-06, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(128), np.int64(16)), mlp__learning_rate_init=0.0002193632253934874; total time=   1.2s
# [CV] END mlp__activation=relu, mlp__alpha=1.0214779573593858e-05, mlp__batch_size=32, mlp__hidden_layer_sizes=(np.int64(128), np.int64(16), np.int64(16)), mlp__learning_rate_init=0.00015406875376373534; total time=   3.1s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0063405102702029405, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(64), np.int64(16), np.int64(16)), mlp__learning_rate_init=0.00034507849212604723; total time=   0.7s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0063405102702029405, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(64), np.int64(16), np.int64(16)), mlp__learning_rate_init=0.00034507849212604723; total time=   0.6s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0063405102702029405, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(64), np.int64(16), np.int64(16)), mlp__learning_rate_init=0.00034507849212604723; total time=   0.7s
# [CV] END mlp__activation=tanh, mlp__alpha=1.921891493444216e-06, mlp__batch_size=32, mlp__hidden_layer_sizes=(np.int64(16), np.int64(16)), mlp__learning_rate_init=0.0008810219121568473; total time=   0.5s
# [CV] END mlp__activation=tanh, mlp__alpha=1.921891493444216e-06, mlp__batch_size=32, mlp__hidden_layer_sizes=(np.int64(16), np.int64(16)), mlp__learning_rate_init=0.0008810219121568473; total time=   0.5s
# [CV] END mlp__activation=tanh, mlp__alpha=1.921891493444216e-06, mlp__batch_size=32, mlp__hidden_layer_sizes=(np.int64(16), np.int64(16)), mlp__learning_rate_init=0.0008810219121568473; total time=   0.5s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0063405102702029405, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(64), np.int64(16), np.int64(16)), mlp__learning_rate_init=0.00034507849212604723; total time=   1.0s
# [CV] END mlp__activation=tanh, mlp__alpha=0.004261089525765805, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(16), np.int64(16)), mlp__learning_rate_init=0.0004599324101889795; total time=   0.3s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0063405102702029405, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(64), np.int64(16), np.int64(16)), mlp__learning_rate_init=0.00034507849212604723; total time=   1.0s
# [CV] END mlp__activation=tanh, mlp__alpha=0.004261089525765805, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(16), np.int64(16)), mlp__learning_rate_init=0.0004599324101889795; total time=   0.3s
# [CV] END mlp__activation=tanh, mlp__alpha=0.004261089525765805, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(16), np.int64(16)), mlp__learning_rate_init=0.0004599324101889795; total time=   0.3s
# [CV] END mlp__activation=tanh, mlp__alpha=0.004261089525765805, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(16), np.int64(16)), mlp__learning_rate_init=0.0004599324101889795; total time=   0.4s
# [CV] END mlp__activation=tanh, mlp__alpha=0.004261089525765805, mlp__batch_size=128, mlp__hidden_layer_sizes=(np.int64(16), np.int64(16)), mlp__learning_rate_init=0.0004599324101889795; total time=   0.5s
# [CV] END mlp__activation=tanh, mlp__alpha=1.921891493444216e-06, mlp__batch_size=32, mlp__hidden_layer_sizes=(np.int64(16), np.int64(16)), mlp__learning_rate_init=0.0008810219121568473; total time=   1.3s
# [CV] END mlp__activation=relu, mlp__alpha=0.00030908560764746545, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(128), np.int64(16), np.int64(128)), mlp__learning_rate_init=0.0002594090700928465; total time=   0.9s
# [CV] END mlp__activation=relu, mlp__alpha=0.00030908560764746545, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(128), np.int64(16), np.int64(128)), mlp__learning_rate_init=0.0002594090700928465; total time=   1.0s
# [CV] END mlp__activation=relu, mlp__alpha=0.00030908560764746545, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(128), np.int64(16), np.int64(128)), mlp__learning_rate_init=0.0002594090700928465; total time=   1.1s
# [CV] END mlp__activation=relu, mlp__alpha=0.00030908560764746545, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(128), np.int64(16), np.int64(128)), mlp__learning_rate_init=0.0002594090700928465; total time=   1.2s
# [CV] END mlp__activation=tanh, mlp__alpha=1.921891493444216e-06, mlp__batch_size=32, mlp__hidden_layer_sizes=(np.int64(16), np.int64(16)), mlp__learning_rate_init=0.0008810219121568473; total time=   1.7s
# [CV] END mlp__activation=relu, mlp__alpha=0.00014061445029443133, mlp__batch_size=32, mlp__hidden_layer_sizes=(np.int64(16), np.int64(32)), mlp__learning_rate_init=0.0046412412443793665; total time=   0.9s
# [CV] END mlp__activation=relu, mlp__alpha=0.00014061445029443133, mlp__batch_size=32, mlp__hidden_layer_sizes=(np.int64(16), np.int64(32)), mlp__learning_rate_init=0.0046412412443793665; total time=   1.2s
# [CV] END mlp__activation=relu, mlp__alpha=0.00030908560764746545, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(128), np.int64(16), np.int64(128)), mlp__learning_rate_init=0.0002594090700928465; total time=   1.3s
# [CV] END mlp__activation=relu, mlp__alpha=0.00014061445029443133, mlp__batch_size=32, mlp__hidden_layer_sizes=(np.int64(16), np.int64(32)), mlp__learning_rate_init=0.0046412412443793665; total time=   0.5s
# [CV] END mlp__activation=relu, mlp__alpha=0.00014061445029443133, mlp__batch_size=32, mlp__hidden_layer_sizes=(np.int64(16), np.int64(32)), mlp__learning_rate_init=0.0046412412443793665; total time=   1.2s
# [CV] END mlp__activation=tanh, mlp__alpha=1.4926407461604497e-05, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(16),), mlp__learning_rate_init=0.004298969371046821; total time=   0.2s
# [CV] END mlp__activation=tanh, mlp__alpha=2.7045998307622466e-06, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(16), np.int64(16), np.int64(16)), mlp__learning_rate_init=0.00027353926063537884; total time=   0.6s
# [CV] END mlp__activation=tanh, mlp__alpha=1.4926407461604497e-05, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(16),), mlp__learning_rate_init=0.004298969371046821; total time=   0.4s
# [CV] END mlp__activation=tanh, mlp__alpha=1.4926407461604497e-05, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(16),), mlp__learning_rate_init=0.004298969371046821; total time=   0.4s
# [CV] END mlp__activation=relu, mlp__alpha=0.00014061445029443133, mlp__batch_size=32, mlp__hidden_layer_sizes=(np.int64(16), np.int64(32)), mlp__learning_rate_init=0.0046412412443793665; total time=   0.9s
# [CV] END mlp__activation=relu, mlp__alpha=0.00029394499135402126, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(64),), mlp__learning_rate_init=0.0057507614754446585; total time=   0.2s
# [CV] END mlp__activation=relu, mlp__alpha=0.00029394499135402126, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(64),), mlp__learning_rate_init=0.0057507614754446585; total time=   0.2s
# [CV] END mlp__activation=tanh, mlp__alpha=2.7045998307622466e-06, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(16), np.int64(16), np.int64(16)), mlp__learning_rate_init=0.00027353926063537884; total time=   0.9s
# [CV] END mlp__activation=tanh, mlp__alpha=2.7045998307622466e-06, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(16), np.int64(16), np.int64(16)), mlp__learning_rate_init=0.00027353926063537884; total time=   0.7s
# [CV] END mlp__activation=relu, mlp__alpha=0.00029394499135402126, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(64),), mlp__learning_rate_init=0.0057507614754446585; total time=   0.2s
# [CV] END mlp__activation=tanh, mlp__alpha=1.4926407461604497e-05, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(16),), mlp__learning_rate_init=0.004298969371046821; total time=   0.5s
# [CV] END mlp__activation=tanh, mlp__alpha=1.4926407461604497e-05, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(16),), mlp__learning_rate_init=0.004298969371046821; total time=   0.6s
# [CV] END mlp__activation=relu, mlp__alpha=0.00029394499135402126, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(64),), mlp__learning_rate_init=0.0057507614754446585; total time=   0.3s
# [CV] END mlp__activation=relu, mlp__alpha=0.00029394499135402126, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(64),), mlp__learning_rate_init=0.0057507614754446585; total time=   0.4s
# [CV] END mlp__activation=tanh, mlp__alpha=2.7045998307622466e-06, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(16), np.int64(16), np.int64(16)), mlp__learning_rate_init=0.00027353926063537884; total time=   1.1s
# [CV] END mlp__activation=tanh, mlp__alpha=2.7045998307622466e-06, mlp__batch_size=64, mlp__hidden_layer_sizes=(np.int64(16), np.int64(16), np.int64(16)), mlp__learning_rate_init=0.00027353926063537884; total time=   1.4s
# [CV] END mlp__activation=tanh, mlp__alpha=4.579475683982002e-06, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(128), np.int64(128), np.int64(128)), mlp__learning_rate_init=0.002197283069917799; total time=   1.0s
# [CV] END mlp__activation=tanh, mlp__alpha=4.579475683982002e-06, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(128), np.int64(128), np.int64(128)), mlp__learning_rate_init=0.002197283069917799; total time=   1.1s
# [CV] END mlp__activation=relu, mlp__alpha=0.0031397140667106306, mlp__batch_size=32, mlp__hidden_layer_sizes=(np.int64(32), np.int64(64), np.int64(64)), mlp__learning_rate_init=0.00018322226170674541; total time=   1.2s
# [CV] END mlp__activation=relu, mlp__alpha=0.00027015988102078444, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(16),), mlp__learning_rate_init=0.002734377423602701; total time=   0.3s
# [CV] END mlp__activation=relu, mlp__alpha=0.00027015988102078444, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(16),), mlp__learning_rate_init=0.002734377423602701; total time=   0.3s
# [CV] END mlp__activation=relu, mlp__alpha=0.0031397140667106306, mlp__batch_size=32, mlp__hidden_layer_sizes=(np.int64(32), np.int64(64), np.int64(64)), mlp__learning_rate_init=0.00018322226170674541; total time=   1.6s
# [CV] END mlp__activation=relu, mlp__alpha=0.00027015988102078444, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(16),), mlp__learning_rate_init=0.002734377423602701; total time=   0.4s
# [CV] END mlp__activation=relu, mlp__alpha=0.00027015988102078444, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(16),), mlp__learning_rate_init=0.002734377423602701; total time=   0.3s
# [CV] END mlp__activation=relu, mlp__alpha=0.00027015988102078444, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(16),), mlp__learning_rate_init=0.002734377423602701; total time=   0.3s
# [CV] END mlp__activation=tanh, mlp__alpha=4.579475683982002e-06, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(128), np.int64(128), np.int64(128)), mlp__learning_rate_init=0.002197283069917799; total time=   1.3s
# [CV] END mlp__activation=tanh, mlp__alpha=4.579475683982002e-06, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(128), np.int64(128), np.int64(128)), mlp__learning_rate_init=0.002197283069917799; total time=   1.6s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0019266069836416017, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(64),), mlp__learning_rate_init=0.00010097356418692505; total time=   0.4s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0019266069836416017, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(64),), mlp__learning_rate_init=0.00010097356418692505; total time=   0.5s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0019266069836416017, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(64),), mlp__learning_rate_init=0.00010097356418692505; total time=   0.7s
# [CV] END mlp__activation=tanh, mlp__alpha=4.579475683982002e-06, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(128), np.int64(128), np.int64(128)), mlp__learning_rate_init=0.002197283069917799; total time=   2.2s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0019266069836416017, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(64),), mlp__learning_rate_init=0.00010097356418692505; total time=   0.7s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0019266069836416017, mlp__batch_size=256, mlp__hidden_layer_sizes=(np.int64(64),), mlp__learning_rate_init=0.00010097356418692505; total time=   0.6s
# [CV] END mlp__activation=relu, mlp__alpha=0.0031397140667106306, mlp__batch_size=32, mlp__hidden_layer_sizes=(np.int64(32), np.int64(64), np.int64(64)), mlp__learning_rate_init=0.00018322226170674541; total time=   2.4s
# [CV] END mlp__activation=relu, mlp__alpha=0.0031397140667106306, mlp__batch_size=32, mlp__hidden_layer_sizes=(np.int64(32), np.int64(64), np.int64(64)), mlp__learning_rate_init=0.00018322226170674541; total time=   2.6s
# [CV] END mlp__activation=relu, mlp__alpha=0.0031397140667106306, mlp__batch_size=32, mlp__hidden_layer_sizes=(np.int64(32), np.int64(64), np.int64(64)), mlp__learning_rate_init=0.00018322226170674541; total time=   2.8s
#
# Best CV accuracy: 0.8081
# Best params: {'mlp__activation': 'tanh', 'mlp__alpha': 0.0012282126524008478, 'mlp__batch_size': 128, 'mlp__hidden_layer_sizes': (np.int64(128), np.int64(16)), 'mlp__learning_rate_init': 0.0012700291162301247}
# Test accuracy: 0.7968

# %% [markdown]
# # 8. Ensemble Methods
#
# Ensemble methods combine multiple models to produce better predictions than any single model. The intuition: different models make different errors, so combining them can cancel out individual mistakes.
#
# ## Why Ensemble XGBoost + CatBoost + Random Forest?
#
# These three models complement each other well:
#
# | Model | Strengths | Weaknesses |
# |-------|-----------|------------|
# | **Random Forest** | Robust, handles noise well, low variance | Can underfit complex patterns |
# | **XGBoost** | Excellent at capturing complex patterns | Can overfit, sensitive to hyperparameters |
# | **CatBoost** | Best categorical handling, regularized | Slower training |
#
# ## Ensemble Strategies
#
# 1. **Soft Voting**: Average predicted probabilities, then classify
#    - Works well when models are calibrated
#    - Simple and effective baseline
#
# 2. **Stacking**: Train a meta-learner on base model predictions
#    - Uses cross-validated predictions to avoid leakage
#    - Can learn optimal model weights
#    - Often outperforms simple voting
#
# **Note**: We exclude MLP from the ensemble because:
# - It requires different feature encoding (one-hot vs label)
# - Tree-based models tend to dominate on this type of tabular data
# - Keeping the ensemble homogeneous simplifies the pipeline

# %%
from sklearn.linear_model import LogisticRegression

# ============================================================================
# APPROACH 1: Probability Averaging (Blending)
# ============================================================================
# each model uses its own encoding - we just average their probability outputs

# get probability predictions from each tuned model on their respective test sets
rf_proba = best_rf.predict_proba(X_test)[:, 1]
xgb_proba = best_xgb.predict_proba(X_test_xgb)[:, 1]
catboost_proba = best_catboost.predict_proba(X_test_cat)[:, 1]

# simple average
avg_proba = (rf_proba + xgb_proba + catboost_proba) / 3
avg_pred = (avg_proba >= 0.5).astype(int)
avg_acc = accuracy_score(y_test, avg_pred)

# weighted average (favor gradient boosting models)
weighted_proba = 0.2 * rf_proba + 0.4 * xgb_proba + 0.4 * catboost_proba
weighted_pred = (weighted_proba >= 0.5).astype(int)
weighted_acc = accuracy_score(y_test, weighted_pred)

print("=" * 50)
print("PROBABILITY AVERAGING ENSEMBLE")
print("=" * 50)
print(f"Simple Average (1:1:1)    - Test Accuracy: {avg_acc:.4f}")
print(f"Weighted (RF:XGB:CAT 2:4:4) - Test Accuracy: {weighted_acc:.4f}")

# ============================================================================
# APPROACH 2: Stacking with Logistic Regression Meta-Learner
# ============================================================================
# train a meta-model on the base models' probability predictions

# create stacking features from cross-validated predictions on training set
from sklearn.model_selection import cross_val_predict

# get out-of-fold probability predictions for training data
rf_train_proba = cross_val_predict(best_rf, X_train, y_train, cv=cv, method='predict_proba')[:, 1]
xgb_train_proba = cross_val_predict(best_xgb, X_train_xgb, y_train_xgb, cv=cv, method='predict_proba')[:, 1]
catboost_train_proba = cross_val_predict(best_catboost, X_train_cat, y_train_cat, cv=cv, method='predict_proba')[:, 1]

# stack as features for meta-learner
stack_train = np.column_stack([rf_train_proba, xgb_train_proba, catboost_train_proba])
stack_test = np.column_stack([rf_proba, xgb_proba, catboost_proba])

# train logistic regression meta-learner
meta_learner = LogisticRegression(random_state=42, max_iter=1000)
meta_learner.fit(stack_train, y_train)

# evaluate stacking ensemble
stack_pred = meta_learner.predict(stack_test)
stack_acc = accuracy_score(y_test, stack_pred)

print(f"\nStacking (Logistic Meta)  - Test Accuracy: {stack_acc:.4f}")
print(f"\nMeta-learner coefficients: RF={meta_learner.coef_[0][0]:.3f}, "
      f"XGB={meta_learner.coef_[0][1]:.3f}, CAT={meta_learner.coef_[0][2]:.3f}")

# ============================================================================
# SUMMARY: Compare all models
# ============================================================================
print("\n" + "=" * 50)
print("MODEL COMPARISON SUMMARY")
print("=" * 50)
results = {
    'Random Forest': rf_test_acc,
    'XGBoost': xgb_test_acc,
    'CatBoost': catboost_test_acc,
    'MLP': mlp_test_acc,
    'Ensemble (Avg)': avg_acc,
    'Ensemble (Weighted)': weighted_acc,
    'Ensemble (Stacking)': stack_acc,
}

for name, acc in sorted(results.items(), key=lambda x: x[1], reverse=True):
    marker = " ★" if acc == max(results.values()) else ""
    print(f"{name:25s} {acc:.4f}{marker}")

# store best ensemble method
best_ensemble_method = max(['avg', 'weighted', 'stack'], 
                           key=lambda x: {'avg': avg_acc, 'weighted': weighted_acc, 'stack': stack_acc}[x])
best_ensemble_acc = max(avg_acc, weighted_acc, stack_acc)
print(f"\nBest ensemble: {best_ensemble_method} with accuracy {best_ensemble_acc:.4f}")
# Out:
# ==================================================
# PROBABILITY AVERAGING ENSEMBLE
# ==================================================
# Simple Average (1:1:1)    - Test Accuracy: 0.8087
# Weighted (RF:XGB:CAT 2:4:4) - Test Accuracy: 0.8064
#
# Stacking (Logistic Meta)  - Test Accuracy: 0.8071
#
# Meta-learner coefficients: RF=0.774, XGB=2.198, CAT=3.029
#
# ==================================================
# MODEL COMPARISON SUMMARY
# ==================================================
# XGBoost                   0.8087 ★
# Ensemble (Avg)            0.8087 ★
# Ensemble (Stacking)       0.8071
# Ensemble (Weighted)       0.8064
# Random Forest             0.8014
# CatBoost                  0.8010
# MLP                       0.7968
#
# Best ensemble: avg with accuracy 0.8087

# %% [markdown]
# # 9. Generate Submission
#
# Use the best performing model or ensemble to predict on the test set and create the submission file for Kaggle.

# %%
# select model for submission
# options: "rf", "xgb", "catboost", "mlp", "ensemble_avg", "ensemble_weighted", "ensemble_stack"
model_name = "rf"

# generate predictions based on selected model
if model_name == "rf":
    submission_features = encode_features_for_ml(test_processed, train_params)
    predictions = best_rf.predict(submission_features)
elif model_name == "xgb":
    predictions = best_xgb.predict(test_xgb)
elif model_name == "catboost":
    predictions = best_catboost.predict(test_cat)
elif model_name == "mlp":
    submission_features = encode_features_for_ml(test_processed, train_params)
    predictions = best_mlp.predict(submission_features)
elif model_name.startswith("ensemble"):
    # get probabilities from each base model
    test_rf_proba = best_rf.predict_proba(encode_features_for_ml(test_processed, train_params))[:, 1]
    test_xgb_proba = best_xgb.predict_proba(test_xgb)[:, 1]
    test_cat_proba = best_catboost.predict_proba(test_cat)[:, 1]
    
    if model_name == "ensemble_avg":
        final_proba = (test_rf_proba + test_xgb_proba + test_cat_proba) / 3
        predictions = (final_proba >= 0.5).astype(int)
    elif model_name == "ensemble_weighted":
        final_proba = 0.2 * test_rf_proba + 0.4 * test_xgb_proba + 0.4 * test_cat_proba
        predictions = (final_proba >= 0.5).astype(int)
    elif model_name == "ensemble_stack":
        test_stack = np.column_stack([test_rf_proba, test_xgb_proba, test_cat_proba])
        predictions = meta_learner.predict(test_stack)
else:
    raise ValueError(f"Unknown model: {model_name}")

# create submission DataFrame
submission = pd.DataFrame({
    'PassengerId': test_raw['PassengerId'],
    'Transported': predictions.astype(bool)
})

# save to CSV
submission.to_csv('submission.csv', index=False)

print(f"Submission saved with {len(submission)} predictions using {model_name.upper()}")
submission.head()
# Out:
# Submission saved with 4277 predictions using RF
#   PassengerId  Transported
# 0     0013_01         True
# 1     0018_01        False
# 2     0019_01         True
# 3     0021_01         True
# 4     0023_01        False
